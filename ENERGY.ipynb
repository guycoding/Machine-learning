# %% [markdown]
# <a href="https://colab.research.google.com/github/guycoding/Machine-learning/blob/main/ENERGY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import root_mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# %%
#Import Data
df = pd.read_csv("/content/PJME_hourly.csv")
df

# %%
df.index = pd.to_datetime(df.index)
df.plot(style = ".", figsize=(15,10), title = "Energy over Time")
# Out:
#                                           Datetime  PJME_MW
# 1970-01-01 00:00:00.000000000  2002-12-31 01:00:00  26498.0
# 1970-01-01 00:00:00.000000001  2002-12-31 02:00:00  25147.0
# 1970-01-01 00:00:00.000000002  2002-12-31 03:00:00  24574.0
# 1970-01-01 00:00:00.000000003  2002-12-31 04:00:00  24393.0
# 1970-01-01 00:00:00.000000004  2002-12-31 05:00:00  24860.0
# ...                                            ...      ...
# 1970-01-01 00:00:00.000145361  2018-01-01 20:00:00  44284.0
# 1970-01-01 00:00:00.000145362  2018-01-01 21:00:00  43751.0
# 1970-01-01 00:00:00.000145363  2018-01-01 22:00:00  42402.0
# 1970-01-01 00:00:00.000145364  2018-01-01 23:00:00  40164.0
# 1970-01-01 00:00:00.000145365  2018-01-02 00:00:00  38608.0
#
# [145366 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
train = df.loc[df.index < "01-01-2016"]
test = df.loc[df.index >= "01-01-2016"]

# %%
fig, ax = plt.subplots(figsize = (15,10) )
train.plot(ax = ax, label = "train", title = "train test split" )
test.plot(ax =ax , label = "test")
ax.axvline("01-01-2016", color = "black", ls = "--")
plt.legend(["train", "test"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-15333b1b3901> in <cell line: 0>()
#       1 fig, ax = plt.subplots(figsize = (15,10) )
#       2 train.plot(ax = ax, label = "train", title = "train test split" )
# ----> 3 test.plot(ax =ax , label = "test")
#       4 ax.axvline("01-01-2016", color = "black", ls = "--")
#       5 plt.legend(["train", "test"])
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
df.loc[(df.index > "01-01-2015" )& (df.index < "01-08-2015")].plot(figsize= (10,8),
                                                                  title= "weekly consumption")
plt.legend()
plt.show()

# %%
def features(df):
  df= df.copy
  df["hour"] = df.index.hour
  df["day"] = df.index.day
  df["dayofweek"] = df.index.dayofweek
  df["dayofyear"] = df.index.dayofyear
  df["month"] = df.index.month
  df["year"] = df.index.year
  df["quater"]= df.index.quarter
  return df

# %%
df = features(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bc8798e2ade3> in <cell line: 0>()
# ----> 1 df = features(df)
#
# NameError: name 'features' is not defined
